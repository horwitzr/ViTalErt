# %%
# MIMIC 
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 50)
data_raw_dir = "/Users/rachellehorwitz/Documents/VTAlert/data/raw_mimiciii/"
admissions = pd.read_csv(data_raw_dir +  'ADMISSIONS.csv')

# %%
admissions.head(10)
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0      21          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1      22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2      23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3      24          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4      25          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
# 5      26          26   197661  2126-05-06 15:16:00  2126-05-13 15:00:00
# 6      27          27   134931  2191-11-30 22:16:00  2191-12-03 14:45:00
# 7      28          28   162569  2177-09-01 07:15:00  2177-09-06 16:00:00
# 8      29          30   104557  2172-10-14 14:17:00  2172-10-19 14:37:00
# 9      30          31   128652  2108-08-22 23:27:00  2108-08-30 15:00:00
#
#              DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 0                  NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# ...

# %%
admission_newborn = admissions[admissions['ADMISSION_TYPE']=='NEWBORN']
admission_newborn.shape
# Out:
# (7863, 19)

# %%
admissions_surgery = admissions[admissions['ADMISSION_TYPE']=='ELECTIVE']
admissions_surgery.shape
print('There are ' + str(admissions_surgery.shape[0]) + ' admissions for surgery')
print('Of the ' + str(admissions_surgery.shape[0]) + ' admissions for surgery, ' + str(admissions_surgery['SUBJECT_ID'].unique().shape[0]) + ' are unique subjects')
# Out:
# There are 7706 admissions for surgery
# Of the 7706 admissions for surgery, 7265 are unique subjects

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
data_raw_dir = "/Users/rachellehorwitz/Documents/VTAlert/data/raw_mimiciii/"
admissions = pd.read_csv(data_raw_dir +  'ADMISSIONS.csv')

# %%
admissions.head(30)
# Out:
#     ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0       21          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1       22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2       23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3       24          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4       25          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
# 5       26          26   197661  2126-05-06 15:16:00  2126-05-13 15:00:00
# 6       27          27   134931  2191-11-30 22:16:00  2191-12-03 14:45:00
# 7       28          28   162569  2177-09-01 07:15:00  2177-09-06 16:00:00
# 8       29          30   104557  2172-10-14 14:17:00  2172-10-19 14:37:00
# 9       30          31   128652  2108-08-22 23:27:00  2108-08-30 15:00:00
# 10      31          32   175413  2170-04-04 08:00:00  2170-04-23 12:45:00
# 11      32          33   176176  2116-12-23 22:30:00  2116-12-27 12:05:00
# ...

# %%
admissions_surgery.head(10)
# Out:
#     ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 1       22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 7       28          28   162569  2177-09-01 07:15:00  2177-09-06 16:00:00
# 10      31          32   175413  2170-04-04 08:00:00  2170-04-23 12:45:00
# 14      35          35   166707  2122-02-10 11:15:00  2122-02-20 15:30:00
# 17      38          36   165660  2134-05-10 11:30:00  2134-05-20 13:16:00
# 21      42          41   101757  2132-12-31 10:30:00  2133-01-27 15:45:00
# 41     475         369   145787  2142-10-09 07:15:00  2142-10-16 14:20:00
# 50      48          49   190539  2186-11-21 07:15:00  2186-11-28 14:05:00
# 62      60          61   176332  2118-06-17 14:40:00  2118-07-20 12:30:00
# 79      77          75   112086  2147-04-05 08:00:00  2147-04-11 14:45:00
#
#    DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 1        NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# ...

# %%
u_hadm_id = admissions_surgery['SUBJECT_ID'].unique().shape[0]

# %%
import pandas as pd
#pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 30)
data_raw_dir = "/Users/rachellehorwitz/Documents/VTAlert/data/raw_mimiciii/"
diagnoses_icd = pd.read_csv(data_raw_dir +  'DIAGNOSES_ICD.csv')
d_icd_diagnoses = pd.read_csv(data_raw_dir + "D_ICD_DIAGNOSES.csv")

# %%
diagnoses_icd.shape
# Out:
# (651047, 5)

# %%
diagnoses_icd.head(29)
# Out:
#     ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0     1297         109   172335      1.0     40301
# 1     1298         109   172335      2.0       486
# 2     1299         109   172335      3.0     58281
# 3     1300         109   172335      4.0      5855
# 4     1301         109   172335      5.0      4254
# 5     1302         109   172335      6.0      2762
# 6     1303         109   172335      7.0      7100
# 7     1304         109   172335      8.0      2767
# 8     1305         109   172335      9.0      7243
# 9     1306         109   172335     10.0     45829
# 10    1307         109   172335     11.0      2875
# 11    1308         109   172335     12.0     28521
# 12    1309         109   172335     13.0     28529
# 13    1310         109   172335     14.0     27541
# 14    1311         109   173633      1.0     40301
# 15    1312         109   173633      2.0      5856
# 16    1313         109   173633      3.0     58381
# ...

# %%
d_icd_diagnoses.head(1000)
# Out:
#      ROW_ID ICD9_CODE               SHORT_TITLE  \
# 0       174     01166     TB pneumonia-oth test
# 1       175     01170    TB pneumothorax-unspec
# 2       176     01171   TB pneumothorax-no exam
# 3       177     01172  TB pneumothorx-exam unkn
# 4       178     01173  TB pneumothorax-micro dx
# ..      ...       ...                       ...
# 995    1376      1023    Hyperkeratosis of yaws
# 996    1377      1024  Gummata and ulcers, yaws
# 997    1378      1025                   Gangosa
# 998    1379      1026      Yaws of bone & joint
# 999    1380      1027   Yaws manifestations NEC
#
#                                                                                                                                                                             LONG_TITLE
# 0    Tuberculous pneumonia [any form], tubercle bacilli not found by bacteriological or histological examination, but tuberculosis confirmed by other methods [inoculation of animals]
# ...

# %%
embolism_diagnoses_all = d_icd_diagnoses[d_icd_diagnoses.LONG_TITLE.str.find('embolism')>0]

# %%
embolism_diagnoses_all.shape
# Out:
# (83, 4)

# %%
embolism_diagnoses_all.head(30)
# Out:
#       ROW_ID ICD9_CODE               SHORT_TITLE  \
# 4245    4246     44409  Ot art emb/thrm abd aort
# 4247    4248     44421  Upper extremity embolism
# 4248    4249     44422  Lower extremity embolism
# 4252    4253     44501  Atheroembolism,upper ext
# 4253    4254     44502  Atheroembolism,lower ext
# 4254    4255     44581    Atheroembolism, kidney
# 4255    4256     44589  Atheroembolism, site NEC
# 4282    4283       449  Septic arterial embolism
# 4296    4297      4532  Oth inf vena cava thromb
# 4297    4298      4533     Renal vein thrombosis
# 4390    4391     41511  Iatrogen pulm emb/infarc
# 4391    4392     41512  Septic pulmonary embolsm
# 4393    4394     41519    Pulm embol/infarct NEC
# 4396    4397      4162    Chr pulmonary embolism
# 4958    5338     45340   Ac DVT/embl low ext NOS
# 4959    5339     45341   Ac DVT/emb prox low ext
# 4960    5340     45342  Ac DVT/emb distl low ext
# 4961    5341     45350   Ch DVT/embl low ext NOS
# ...

# %%
dvt_all = d_icd_diagnoses[d_icd_diagnoses.SHORT_TITLE.str.find('DVT')>0]

# %%
dvt_all.shape
# Out:
# (8, 4)

# %%
vte_diagnoses_all = d_icd_diagnoses[d_icd_diagnoses.LONG_TITLE.str.find('venous')>0]

# %%
vte_diagnoses_all.shape
# Out:
# (55, 4)

# %%
vte_diagnoses_all.head(80)
# Out:
#        ROW_ID ICD9_CODE               SHORT_TITLE  \
# 3102     3103       325  Phlebitis intrcran sinus
# 3732     4117     36582  Glauc w inc episcl press
# 4266     4267      4470    Acq arterioven fistula
# 4296     4297      4532  Oth inf vena cava thromb
# 4297     4298      4533     Renal vein thrombosis
# ...       ...       ...                       ...
# 12613    9715     67192  Ven comp NOS-deliv w p/p
# 12614    9716     67193  Venous compl NOS-antepar
# 12615    9717     67194  Venous compl NOS-postpar
# 13372   13945     V1251  Hx-ven thrombosis/embols
# 13913   11349      9683  Poison-intraven anesthet
#
#                                                                                                                 LONG_TITLE
# 3102                                                         Phlebitis and thrombophlebitis of intracranial venous sinuses
# ...

# %%
embolism_diagnoses_all.shape
# Out:
# (83, 4)

# %%
diagnoses_icd.head(30)
# Out:
#     ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0     1297         109   172335      1.0     40301
# 1     1298         109   172335      2.0       486
# 2     1299         109   172335      3.0     58281
# 3     1300         109   172335      4.0      5855
# 4     1301         109   172335      5.0      4254
# 5     1302         109   172335      6.0      2762
# 6     1303         109   172335      7.0      7100
# 7     1304         109   172335      8.0      2767
# 8     1305         109   172335      9.0      7243
# 9     1306         109   172335     10.0     45829
# 10    1307         109   172335     11.0      2875
# 11    1308         109   172335     12.0     28521
# 12    1309         109   172335     13.0     28529
# 13    1310         109   172335     14.0     27541
# 14    1311         109   173633      1.0     40301
# 15    1312         109   173633      2.0      5856
# 16    1313         109   173633      3.0     58381
# ...

# %%
# in diagnoses_icd
