# %%
# EICU
import pandas as pd
pd.set_option('display.max_colwidth', -1)
data_raw_dir = "~/Documents/VTAlert/data/raw/"
admissiondx = pd.read_csv(data_raw_dir + 'admissionDx.csv')
diagnosis = pd.read_csv(data_raw_dir + 'diagnosis.csv')
customLab = pd.read_csv(data_raw_dir + 'customLab.csv')
# Out:
# /Users/rachellehorwitz/opt/anaconda3/envs/insight/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
# MIMIC 
import pandas as pd
pd.set_option('display.max_colwidth', None)
data_raw_dir = "/Users/rachellehorwitz/Documents/VTAlert/data/raw_mimiciii/"
admissions = pd.read_csv(data_raw_dir +  'ADMISSIONS.csv')

# %%
admissions.head(10)
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0      21          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1      22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2      23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3      24          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4      25          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
# 5      26          26   197661  2126-05-06 15:16:00  2126-05-13 15:00:00
# 6      27          27   134931  2191-11-30 22:16:00  2191-12-03 14:45:00
# 7      28          28   162569  2177-09-01 07:15:00  2177-09-06 16:00:00
# 8      29          30   104557  2172-10-14 14:17:00  2172-10-19 14:37:00
# 9      30          31   128652  2108-08-22 23:27:00  2108-08-30 15:00:00
#
#              DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 0                  NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# ...

# %%
admissions_surgery = admissions[admissions['ADMISSION_TYPE']=='ELECTIVE']
admissions_surgery.shape
# Out:
# (7706, 19)

# %%
# Out:
# (0, 19)

# %%
admissions.head(10)
# Out:
#    row_id  subject_id  hadm_id            admittime            dischtime  \
# 0   12258       10006   142345  2164-10-23 21:09:00  2164-11-01 17:15:00
# 1   12263       10011   105331  2126-08-14 22:32:00  2126-08-28 18:59:00
# 2   12265       10013   165520  2125-10-04 23:36:00  2125-10-07 15:13:00
# 3   12269       10017   199207  2149-05-26 17:19:00  2149-06-03 18:42:00
# 4   12270       10019   177759  2163-05-14 20:43:00  2163-05-15 12:00:00
# 5   12277       10026   103770  2195-05-17 07:39:00  2195-05-24 11:45:00
# 6   12278       10027   199395  2190-07-13 07:15:00  2190-07-25 14:00:00
# 7   12280       10029   132349  2139-09-22 10:58:00  2139-10-02 14:29:00
# 8   12282       10032   140372  2138-04-02 19:52:00  2138-04-15 14:35:00
# 9   12283       10033   157235  2132-12-05 02:46:00  2132-12-08 15:15:00
#
#              deathtime admission_type         admission_location  \
# 0                  NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# ...
